# %%
import dill

# %%
with open("../data/dart_report_20240320_20240320.pkl", "rb") as f:
    loaded_data = dill.load(f)

# %%
len(loaded_data)
# Out:
# 10

# %%
loaded_data[-1]
# Out:
# {'corp_code': '01416642',
#  'corp_name': '다보링크',
#  'report_nm': '사업보고서 (2023.12)',
#  'document': [{'title': '사 업 보 고 서',
#    'text': '\n사 업 보 고 서\n\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 (제 05 기)\n사업연도\n2023년 01월 01일\n\xa0부터\n2023년 12월 31일\n\xa0까지\n금융위원회\n한국거래소 귀중\n2024년 \xa003월 \xa020일\n제출대상법인 유형 :\n주권상장법인\n면제사유발생 :\n해당사항 없음\n회 \xa0 \xa0 \xa0사 \xa0 \xa0 \xa0명 :\n주식회사 다보링크\n대 \xa0 표 \xa0 \xa0이 \xa0 사 :\n임 상 현, 이민수\n본 \xa0점 \xa0소 \xa0재 \xa0지 :\n경기도 안양시 동안구 벌말로 112(관양동)\n(전 \xa0화) 031-387-3240\n(홈페이지) http://www.davolink.co.kr\n작 \xa0성 \xa0책 \xa0임 \xa0자 :\n(직 \xa0책) 이사 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0(성 \xa0명) 주정덕\n(전 \xa0화) 031-387-3240\n'},
#   {'title': '【 대표이사 등의 확인 】', 'text': '\n【 대표이사 등의 확인 】\n대표이사 등의 확인 서명\n'},
#   {'title': 'I. 회사의 개요',
# ...
